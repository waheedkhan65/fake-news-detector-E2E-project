# %%
import pandas as pd 
df_fake = pd.read_csv('../data/fake.csv')
df_true = pd.read_csv('../data/true.csv')

# %%
df_fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
df_true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
df_fake['label'] = 0
df_true['label'] = 1

# %%
df_fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  label
# 0  December 31, 2017      0
# 1  December 31, 2017      0
# 2  December 30, 2017      0
# 3  December 29, 2017      0
# 4  December 25, 2017      0

# %%
df_true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %% [markdown]
# #### Concatenate and shuffle the dataset after concatenating

# %%
data = pd.concat([df_fake, df_true], axis=0)
data = data.sample(frac=1).reset_index(drop=True)
data.head()
# Out:
#                                                title  \
# 0  REVEALED: Who Gave Democratic Emails To Wikile...
# 1  Egyptian billionaire denounces Saudi corruptio...
# 2   After Being Handed Yet Another Court Loss, Tr...
# 3  COMCAST GIVES EMPLOYEES Day Off To PROTEST TRU...
# 4  Congo military plane crashes in Kinshasa, kill...
#
#                                                 text    subject  \
# 0  While all of the mainstream media and anonymou...  left-news
# 1  ROME (Reuters) - Egyptian billionaire business...  worldnews
# 2  Donald Trump hates losing. Not because it s a ...       News
# 3  Wow! I was just getting ready to switch our TV...  left-news
# 4  KINSHASA (Reuters) - A military cargo plane cr...  worldnews
#
#                   date  label
# 0         Dec 19, 2016      0
# 1    December 1, 2017       1
# 2       April 26, 2017      0
# 3          Feb 3, 2017      0
# 4  September 30, 2017       1

# %%
from src.data_utils import load_data
data = load_data('../data/fake.csv', '../data/true.csv')
data.head()

# %%
cd "c:\Users\My Pc\Desktop\project ML new"
# Out:
# c:\Users\My Pc\Desktop\project ML new

# %%
from src.data_utils import load_data
data = load_data('data/fake.csv', 'data/true.csv')
data.head()
# Out:
#                                                 text  label
# 0  washington  reuters    democratic presumptive ...      1
# 1  we reported earlier today that  chuck and nanc...      0
# 2   century wire says the field is now clear for ...      0
# 3  jerusalem  reuters    israel said on sunday it...      1
# 4  there s so much to know in order to understand...      0
