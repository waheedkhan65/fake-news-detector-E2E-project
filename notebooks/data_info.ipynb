# %%
import pandas as pd 
df_fake = pd.read_csv('../data/fake.csv')
df_true = pd.read_csv('../data/true.csv')

# %%
df_fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
df_true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
df_fake['label'] = 0
df_true['label'] = 1

# %%
df_fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  label
# 0  December 31, 2017      0
# 1  December 31, 2017      0
# 2  December 30, 2017      0
# 3  December 29, 2017      0
# 4  December 25, 2017      0

# %%
df_fake = df_fake.drop(df_fake.index[21418:-1])

# %%
df_true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %% [markdown]
# #### Concatenate and shuffle the dataset after concatenating

# %%
data = pd.concat([df_fake, df_true], axis=0)
data = data.sample(frac=1).reset_index(drop=True)
data.head()
# Out:
#                                                title  \
# 0  Immigration overhaul backers sing, dance, chan...
# 1   Lifetime Republican Voter Thanks President Ob...
# 2  U.S. commerce chief says he is likely to dives...
# 3   President Obama Defends Kaepernick’s Protest ...
# 4  German coalition talks stumble on migration, c...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - Dancing, singing, chant...  politicsNews
# 1  Republican lawmakers hate Obamacare, but it s ...          News
# 2  WASHINGTON (Reuters) - U.S. Commerce Secretary...  politicsNews
# 3  Conservatives are throwing a collective hissy ...          News
# 4  BERLIN (Reuters) - Three German parties resign...     worldnews
#
#                 date
# 0    April 18, 2016
# 1      March 4, 2016
# 2  November 6, 2017
# 3  September 5, 2016
# 4  October 26, 2017

# %%
from src.data_utils import load_data
data = load_data('data/fake.csv', 'data/true.csv')
data.head()
# Out:
#                                                 text  label
# 0  there have recently been allegations claiming ...      0
# 1  it s too early to endorse hillary  what s al g...      0
# 2  barack obama and first lady  michelle  attende...      0
# 3  ottawa  reuters    canada will make an announc...      1
# 4  new york  reuters    the mayor of paterson  ne...      1

# %%
cd ..
# Out:
# c:\Users\My Pc\Desktop\project ML

# %%
pwd
# Out:
# 'c:\\Users\\My Pc\\Desktop\\project ML'
